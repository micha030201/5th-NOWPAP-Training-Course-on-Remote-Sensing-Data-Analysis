# %% [markdown]
# <img src="../images/5thNRST_logo.png" alt="Girl in a jacket" width="900" height="700">
#
# ## NOWPAP REMOTE SENSING TRAINING COURSE
#
# #### Webinar 2: Monitoring and Assessment of Water Quality by Ocean Color Remote Sensing
# <span style="color:brown; font-size:1.1em;font-style:italic">  Understanding level-2 flag information: Working with swath imagery</span>
# <hr style="border:2px solid rgb(30,70,125)"> </hr>
#
#
# <span style="font-family:Helvieta; font-size:2em;">Eligio Maure (maure@npec.or.jp)</span>

# %% [markdown]
# ***
# **Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# # Table of contents
# - [1. Purpose](#1.-Purpose)
# - [2. Library import](#2.-Library-import)
# - [3. Exercise with MODIS-Aqua](#3.-Exercise-with-MODIS-Aqua)
# - [4. Exercise with SGLI/GCOM-C ](#4.-Exercise-with-SGLI/GCOM-C)
# - [5. Resources](#5.-Resources)
# ***

# %% [markdown]
# # 1. Purpose
# [Return to the "Table of contents"](#Table-of-contents)
#
# The objective of this exercise is to explore the flags that are used to indicate quality of Level 2 Ocean Color products.
#
# These flags define the conditions that make it impossible to calculate any meaningful Level 2 parameters.
#
# You will learn how to read level 2 products and display flag information to learn about the flags that invalidate the pixels.
# ***

# %% [markdown]
# # 2. Library import
# [Return to the "Table of contents"](#Table-of-contents)
#
# Start by importing require modules for data analysis
# If a module throws a `ModuleNotFoundError` install it with the command
# `!conda install --channel "conda-forge" module`

# %%
# !pip install numpy netcdf4 pyproj tqdm opencv-python requests scipy h5py matplotlib
# Out:
# Requirement already satisfied: numpy in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (1.21.4)
# Requirement already satisfied: netcdf4 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (1.5.8)
# Requirement already satisfied: pyproj in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (3.3.0)
# Requirement already satisfied: tqdm in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (4.62.3)
# Requirement already satisfied: opencv-python in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (4.5.4.60)
# Requirement already satisfied: requests in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (2.26.0)
# Requirement already satisfied: scipy in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (1.7.3)
# Requirement already satisfied: h5py in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (3.6.0)
# Requirement already satisfied: matplotlib in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: cftime in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from netcdf4) (1.5.1.1)
# Requirement already satisfied: certifi in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from pyproj) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from requests) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from requests) (2.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from matplotlib) (4.28.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/micha/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis/.env/bin/python -m pip install --upgrade pip' command.

# %%
# Data manipulation
import numpy as np

# Library import
import h5py 
from netCDF4 import Dataset

# System
import sys
from pathlib import Path

# Visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# - **Local modules**
# Include a local library (scripts) from where we import our custom fuctions.
# To be able to do so, we append the path of where the custom functions are saved before importing.

# %%
sys.path.append(str(Path('.').absolute().parent)) 
import sutils as util

# %% [markdown]
# # 3. Exercise with MODIS-Aqua
# [Return to the "Table of contents"](#Table-of-contents)

# %%
# Define and read data (MODIS-Aqua)
nc_file = Path('sample_data/A2021097040500.L2_LAC_OC.nc').absolute()
with Dataset(nc_file, 'r') as nc:
    lon = nc.groups['navigation_data']['longitude'][:]
    lat = nc.groups['navigation_data']['latitude'][:]
    flags = nc.groups['geophysical_data']['l2_flags'][:]
    chl = np.log10(nc.groups['geophysical_data']['chlor_a'][:])
# Out:
# /tmp/ipykernel_878793/3790584781.py:7: RuntimeWarning: invalid value encountered in log10
#   chl = np.log10(nc.groups['geophysical_data']['chlor_a'][:])

# %% [markdown]
# - **MODIS-Aqua level-2 flag meaning**

# %% [markdown]
# ```javascript
# flag_means = {0: 'ATMFAIL',    1: 'LAND',        2: 'PRODWARN',
#               3: 'HIGLINT',    4: 'HILT',        5: 'HISATZEN',
#               6: 'COASTZ',     7: 'SPARE',       8: 'STRAYLIGHT',
#               9: 'CLDICE',    10: 'COCCOLITH',  11: 'TURBIDW',
#               12: 'HISOLZEN', 13: 'SPARE',      14: 'LOWLW',
#               15: 'CHLFAIL',  16: 'NAVWARN',    17: 'ABSAER',
#               18: 'SPARE',    19: 'MAXAERITER', 20: 'MODGLINT',
#               21: 'CHLWARN',  22: 'ATMWARN',    23: 'SPARE',
#               24: 'SEAICE',   25: 'NAVFAIL',    26: 'FILTER',
#               27: 'SPARE',    28: 'BOWTIEDEL',  29: 'HIPOL',
#               30: 'PRODFAIL', 31: 'SPARE'};
# ```

# %% [markdown]
# - **Define a function to retrieve the flag-bit information**

# %%
def get_flag_mask(bit: int, l2_flags):
    mask = l2_flags & (1 << bit)
    return np.ma.masked_where(mask==0, mask)

# %% [markdown]
# - **Explore the L2 flags**

# %%
bit = 9
fmask = get_flag_mask(bit=bit, l2_flags=flags); 

fig, ax = plt.subplots(1,2, figsize=(20,8), sharey=True)
ax[0].pcolormesh(lon, lat, fmask, cmap='jet')
ax[1].pcolormesh(lon, lat, chl, cmap='jet')

if bit != 1:
    util.add_coastline(ax=ax[0])
    util.add_coastline(ax=ax[1])
# Out:
# /tmp/ipykernel_878793/2480526574.py:5: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   ax[0].pcolormesh(lon, lat, fmask, cmap='jet')
# /tmp/ipykernel_878793/2480526574.py:6: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   ax[1].pcolormesh(lon, lat, chl, cmap='jet')
# .
# .

# %% [markdown]
# # 4. Exercise with SGLI/GCOM-C
# [Return to the "Table of contents"](#Table-of-contents)
# - Try it - 5 min

# %% [markdown]
# - **SGLI/GCOM-C level-2 flag meaning**

# %% [markdown]
# ```javascript
# flag_means = {0: 'DATAMISS',  1: "LAND",
#               2: 'ATMFAIL',   3: "CLDICE",
#               4: "CLDAFFCTD", 5: "STRAYLIGHT",
#               6: "HIGLINT",   7: "MODGLINT",
#               8: 'HISOLZ',    9: 'HITAUA',
#               10: 'NEGNLW',   11: 'TURBIDW',
#               12: 'SHALLOW',  13: "ITERFAILCDOM",
#               14: 'CHLWARN',  15: 'SPARE'};
# ```

# %%
# Define and read data
h5_file = Path('sample_data/GC1SG1_201905270131G05010_L2SG_IWPRQ_2000.h5').absolute()

lat = util.navigation_data(file=h5_file, key='lat')
lon = util.navigation_data(file=h5_file, key='lon')

flags = util.h5_read(file=h5_file, key='QA_flag')
chl = np.log10(util.h5_read(file=h5_file, key='CHLA'))
# Out:
# /tmp/ipykernel_878793/2503805197.py:8: RuntimeWarning: invalid value encountered in log10
#   chl = np.log10(util.h5_read(file=h5_file, key='CHLA'))

# %%
bit = 3
fmask = get_flag_mask(bit=bit, l2_flags=flags); 

fig, ax = plt.subplots(1,2, figsize=(20,8), sharey=True)
ax[0].pcolormesh(lon, lat, fmask, cmap='jet')
ax[1].pcolormesh(lon, lat, chl, cmap='jet')

if bit != 1:
    util.add_coastline(ax=ax[0])
    util.add_coastline(ax=ax[1])
# Out:
# .
# .

# %% [markdown]
# <div class="alert alert-block alert-success"/div>
#     <b>Done!</b><br>
#
# ---
#
# #### And thank you for your attention! :)
#     Now try the same exercise with other sensors including GOCI, VIIRS, etc.
#     We hope you enjoyed the training provided by NOWPAP CEARAC.

# %% [markdown]
# # 5. Resources
# [Go back to the "Table of contents"](#Table-of-contents)
# 1. https://oceancolor.gsfc.nasa.gov/atbd/ocl2flags/
# 2. https://global.jaxa.jp/projects/sat/gcom_c/
# 3. https://ocean.nowpap3.go.jp/
# 4. https://github.com/npec/5th-NOWPAP-Training-Course-on-Remote-Sensing-Data-Analysis
